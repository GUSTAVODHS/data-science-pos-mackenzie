# %% [markdown]
# <a href="https://colab.research.google.com/github/GUSTAVODHS/data-science-pos-mackenzie/blob/main/Trilha7_GGPLOT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(ggplot2)

# %%
ggplot(data=diamonds, aes(x=price,y=carat))
# Out:
# plot without title

# %%
ggplot(data = diamonds, aes(x = carat, y = price)) + 
  geom_point(col = "darkcyan", aes(size = 1)) +
  ggtitle("Análise de Diamantes", subtitle = "Peso x Preço") +
  xlab("Peso do Diamante") +
  ylab("Preço do Diamante")
# Out:
# plot without title

# %%
ggplot(data = diamonds, aes(x = carat, y = price)) + 
  geom_point(aes(col = clarity, size = carat)) +
  ggtitle("Análise de Diamantes", subtitle = "Peso x Preço") +
  xlab("Peso do Diamante") +
  ylab("Preço do Diamante")
# Out:
# plot without title

# %%
ggplot(data = diamonds, aes(x = carat, y = price)) + 
  geom_point(aes(col = clarity, size = carat)) +
  ggtitle("Análise de Diamantes", subtitle = "Peso x Preço") +
  xlab("Peso do Diamante") +
  ylab("Preço do Diamante") +
  theme_bw()
# Out:
# plot without title

# %%
ggplot(data = diamonds, aes(x = carat, y = price)) + 
  geom_point() +
  geom_smooth() +
  ggtitle("Análise de Diamantes", subtitle = "Peso x Preço") +
  xlab("Peso do Diamante") +
  ylab("Preço do Diamante")
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %%
ggplot(data = diamonds, aes(x = carat, y = price)) + 
  geom_point(aes(col = clarity), size = 1) +
  geom_smooth(aes(x = carat, y = price, col = clarity)) +
  ggtitle("Análise de Diamantes", subtitle = "Peso x Preço") +
  xlab("Peso do Diamante") +
  ylab("Preço do Diamante")
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %%
ggplot(data = diamonds, aes(x = carat, y = price)) + 
  geom_point(aes(col = clarity), size = 1) +
  geom_smooth(aes(x = carat, y = price, col = clarity)) +
  ggtitle("Análise de Diamantes", subtitle = "Peso x Preço") +
  xlab("Peso do Diamante") +
  ylab("Preço do Diamante") +
  facet_wrap( ~ clarity)
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %%
library(RColorBrewer)
display.brewer.all()
# Out:
# plot without title

# %%
graficoDiamantes <- 
  ggplot(diamonds, aes(x = color, fill = clarity)) +
  geom_bar(position = 'fill') +
  xlab('Cores do Diamantes \n de D (melhor) até J (pior)') +
  ylab('Proporções') + 
  labs(fill = 'Claridade do diamante \n de I1 (pior) até IF (melhor)') +
  facet_grid(. ~ cut) +
  ggtitle("Detalhes dos diamantes!")

graficoDiamantes
# Out:
# plot without title
